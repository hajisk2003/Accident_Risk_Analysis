# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as  sbrn

# %%
df = pd.read_csv("Cleandata.csv")
df
# Out:
#         Unnamed: 0.1  Unnamed: 0  Year  Severity  Start_Lat   Start_Lng  \
# 0                  0           2  2016         2  39.063148  -84.032608
# 1                  1           3  2016         3  39.747753  -84.205582
# 2                  2           4  2016         2  39.627781  -84.188354
# 3                  3           5  2016         3  40.100590  -82.925194
# 4                  4           6  2016         2  39.758274  -84.230507
# ...              ...         ...   ...       ...        ...         ...
# 314280        314280     7652504  2017         2  28.879630  -82.092960
# 314281        314281     7652579  2017         2  37.993881  -92.795869
# 314282        314282     7652658  2017         2  46.617235 -113.051251
# 314283        314283     7653119  2017         4  46.672100 -113.153690
# 314284        314284     7653237  2017         3  34.344290 -118.504950
#
#         Distance(mi)                     Street          City       County  \
# ...

# %%
df = df.drop(columns=['Unnamed: 0.1','Unnamed: 0'])
df
# Out:
#         Year  Severity  Start_Lat   Start_Lng  Distance(mi)  \
# 0       2016         2  39.063148  -84.032608         0.010
# 1       2016         3  39.747753  -84.205582         0.010
# 2       2016         2  39.627781  -84.188354         0.010
# 3       2016         3  40.100590  -82.925194         0.010
# 4       2016         2  39.758274  -84.230507         0.000
# ...      ...       ...        ...         ...           ...
# 314280  2017         2  28.879630  -82.092960         0.722
# 314281  2017         2  37.993881  -92.795869         0.000
# 314282  2017         2  46.617235 -113.051251         0.000
# 314283  2017         4  46.672100 -113.153690         9.486
# 314284  2017         3  34.344290 -118.504950         0.430
#
#                            Street          City       County State  \
# 0                  State Route 32  Williamsburg     Clermont    OH
# 1                          I-75 S        Dayton   Montgomery    OH
# ...

# %%
fig, ax = plt.subplots(figsize = (10,5))
c = sbrn.countplot(x="Year", data=df)
c.set_title("No. of Accidents in Year 2016 to 2018")
for i in ax.patches:
    count = '{:,.0f}'.format(i.get_height())
    x = i.get_x()+i.get_width()-0.60
    y = i.get_height()+1000
    ax.annotate(count, (x, y))
plt.show()

# %%
df['State'].value_counts()[:10].plot(kind='barh')
plt.title('Top 10 2016 to 2018 State')
# Out:
# Text(0.5, 1.0, 'Top 10 2016 to 2018 State')

# %%
df2016 = df[df['Year']==2016]
df2017 = df[df['Year']==2017]
df2018 = df[df['Year']==2018]

# %%
df['City'].value_counts()[:10].plot(kind='barh')
plt.title('Top 10 2016 to 2018 City')
# Out:
# Text(0.5, 1.0, 'Top 10 2016 to 2018 City')

# %%
df2016['State'].value_counts()[:10].plot(kind='barh')
plt.title('Top 10 2016 State')
# Out:
# Text(0.5, 1.0, 'Top 10 2016 State')

# %%
df2017['State'].value_counts()[:10].plot(kind='barh')
plt.title('Top 10 2016 State')
# Out:
# Text(0.5, 1.0, 'Top 10 2016 State')

# %%
df2018['State'].value_counts()[:10].plot(kind='barh')
plt.title('Top 10 2016 State')
# Out:
# Text(0.5, 1.0, 'Top 10 2016 State')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314285 entries, 0 to 314284
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Year               314285 non-null  int64
#  1   Severity           314285 non-null  int64
#  2   Start_Lat          314285 non-null  float64
#  3   Start_Lng          314285 non-null  float64
#  4   Distance(mi)       314285 non-null  float64
#  5   Street             314285 non-null  object
#  6   City               314285 non-null  object
#  7   County             314285 non-null  object
#  8   State              314285 non-null  object
#  9   Airport_Code       314285 non-null  object
#  10  Temperature(F)     314285 non-null  float64
#  11  Wind_Chill(F)      314285 non-null  float64
#  12  Visibility(mi)     314285 non-null  float64
#  13  Wind_Direction     314285 non-null  object
#  14  Weather_Condition  314285 non-null  object
# ...

# %%
df['Weather_Condition'].value_counts()[:10].plot(kind='barh')
plt.title('Top 10 Weather')
# Out:
# Text(0.5, 1.0, 'Top 10 Weather')

# %%
df['Street'].value_counts()[:20].plot(kind='barh')
plt.title('Top 20 Street')
# Out:
# Text(0.5, 1.0, 'Top 20 Street')

# %%
df['Sunrise_Sunset'].value_counts()[:10].plot(kind='barh')
plt.title('Top 10 Weather')
# Out:
# Text(0.5, 1.0, 'Top 10 Weather')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314285 entries, 0 to 314284
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Year               314285 non-null  int64
#  1   Severity           314285 non-null  int64
#  2   Start_Lat          314285 non-null  float64
#  3   Start_Lng          314285 non-null  float64
#  4   Distance(mi)       314285 non-null  float64
#  5   Street             314285 non-null  object
#  6   City               314285 non-null  object
#  7   County             314285 non-null  object
#  8   State              314285 non-null  object
#  9   Airport_Code       314285 non-null  object
#  10  Temperature(F)     314285 non-null  float64
#  11  Wind_Chill(F)      314285 non-null  float64
#  12  Visibility(mi)     314285 non-null  float64
#  13  Wind_Direction     314285 non-null  object
#  14  Weather_Condition  314285 non-null  object
# ...

# %%
min(df['Severity'])
# Out:
# 1

# %%
_1=df[df['Severity']==1]
_1
# Out:
#         Year  Severity  Start_Lat   Start_Lng  Distance(mi)  \
# 148     2016         1  41.395805  -81.935562           0.0
# 321     2016         1  40.018669  -81.565704           0.0
# 1874    2017         1  37.771721 -121.212677           0.0
# 4068    2016         1  34.438126 -118.394073           0.0
# 4359    2016         1  34.274918 -118.690063           0.0
# ...      ...       ...        ...         ...           ...
# 213410  2017         1  29.939335  -95.353249           0.0
# 218046  2017         1  35.631901  -97.567146           0.0
# 226787  2017         1  40.100380  -75.293854           0.0
# 228600  2017         1  47.621071 -122.201691           0.0
# 230473  2017         1  33.416073  -81.786049           0.0
#
#                       Street              City       County State  \
# 148            Maplehurst Rd     North Olmsted     Cuyahoga    OH
# 321         Old Byesville Rd         Cambridge     Guernsey    OH
# ...

# %%
f,ax=plt.subplots(1,1,figsize=(18,8))
df['Severity'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax,shadow=True)
ax.set_title('Percentage Severity Distribution')
ax.set_ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(18,9))
df_num_features = df.select_dtypes(include=np.number)
corr =  df_num_features.corr()
corr =df_num_features.corr(method='pearson')
sbrn.heatmap(corr, annot=True,cmap='tab20c')
plt.show()

# %%
#BoxPlot Histogram TSNE
sbrn.boxplot(data = df, x = "Severity", y = "Temperature(F)")
plt.title("Box plot of Severity and Temperature")
plt.show()

# %%
df_pred = df.copy()

# Keep only model features
model_features = model.get_booster().feature_names
df_pred = df_pred[model_features]

# Convert categoricals
for col in df_pred.select_dtypes(include='object').columns:
    df_pred[col] = df_pred[col].astype('category')

df['Predicted_Severity'] = model.predict(df_pred)

df.to_csv("WebApp/uploads/predicted_output.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       1 df_pred = df.copy()
#       3 # Keep only model features
# ----> 4 model_features = model.get_booster().feature_names
#       5 df_pred = df_pred[model_features]
#       7 # Convert categoricals
#
# NameError: name 'model' is not defined
